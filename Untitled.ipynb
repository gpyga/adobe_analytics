# %%
import sys
sys.path.append('.')
import adobe_analytics
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-c41bf8977b87>", line 3, in <module>
#     import adobe_analytics
#
#   File "/Users/nickolasgryga/work/adobe_analytics/adobe_analytics/__init__.py", line 1, in <module>
#     from adobe_analytics.api import OmnitureApi
#
#   File "/Users/nickolasgryga/work/adobe_analytics/adobe_analytics/api.py", line 1, in <module>
#     from adobe_analytics.session import OmnitureSession
#
#   File "/Users/nickolasgryga/work/adobe_analytics/adobe_analytics/session.py", line 62
#     'PasswordDigest="{digest}", '
#     ^
# IndentationError: unexpected indent
